# %% [markdown]
# <a href="https://colab.research.google.com/github/PHoepner/big-sleep/blob/main/Morph.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# You should be able to just run this as-is (there's examples in the git that gets pulled down). I can try to answer questions at https://www.reddit.com/user/exquisite_corpsed
#
# You're going to need the path files from big-sleep to use this. There's a few examples to test with in the /content/big-sleep/paths folder to play with.

# %%
# !git clone https://github.com/phoepner/big-sleep.git
# !pip install ftfy
# !pip install boto3
# !pip install einops
import subprocess
for _ in range(2):
    CUDA_version = [s for s in subprocess.check_output(["nvcc", "--version"]).decode("UTF-8").split(", ") if s.startswith("release")][0].split(" ")[-1]
    print("CUDA version:", CUDA_version)

    if CUDA_version == "10.0":
        torch_version_suffix = "+cu100"
    elif CUDA_version == "10.1":
        torch_version_suffix = "+cu101"
    elif CUDA_version == "10.2":
        torch_version_suffix = ""
    else:
        torch_version_suffix = "+cu110"

    # !pip install torch==1.7.1{torch_version_suffix} torchvision==0.8.2{torch_version_suffix} -f https://download.pytorch.org/whl/torch_stable.html ftfy regex

# %%
#@title Options { display-mode: "both" }
FileStartIndex =  200#@param {type:"integer"} // this is for the output files. Eg file.FileStartIndex.png
NumberOfFrames = 40 #@param {type:"integer"} // How  many frames you want between the 2 points

# These go in the 'paths' folder in /content/big-sleep/paths on the left. There's 2 examples in there.
FirstPathIndex =  0#@param {type:"integer"} // The beginning path. Eg file.FirstPathIndex.pth
SecondPathIndex =  1#@param {type:"integer"} // The beginning path. Eg file.SecondPathIndex.pth
import time
TIMESTAMP = str(int(time.time()))
print('*******************************')
print('Creating a zip of images named '+TIMESTAMP+'.zip and a video named '+TIMESTAMP+'.mp4' )
print('*******************************')
# %cd /content/big-sleep
# %rm *.png
# !python /content/big-sleep/interpolation.py --lat1 /content/big-sleep/paths/file.$FirstPathIndex\.pth --lat2 /content/big-sleep/paths/file.$SecondPathIndex\.pth --steps $NumberOfFrames --startFileIndex $FileStartIndex
# !ffmpeg -r 12 -start_number $FileStartIndex -i file.%d.png -vf fps=25 -pix_fmt yuv420p $TIMESTAMP\.mp4
# !zip /content/$TIMESTAMP\.zip *.png
